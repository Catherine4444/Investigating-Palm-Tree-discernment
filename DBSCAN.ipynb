# %%
# DBSCAN clustering 
import numpy as np
from sklearn.cluster import  DBSCAN
from sklearn.metrics import confusion_matrix, f1_score, normalized_mutual_info_score, precision_score, recall_score
import pandas as pd
import timeit
import matplotlib.pyplot as plt
import os

# %%
# the method specifies key to make sure the ground truth set is in consistent order as the valeus accessed 
def ground_truth_set(key):
    ground_truth = []
    for item in key:
        if "Palm" in item: 
            ground_truth.append(1)
        else:
            ground_truth.append(0)
    
    return np.array(ground_truth)

def data_set(key, dict):
    data = []
    for item in key:
        data.append(dict[item])
    return np.array(data)

def get_truth_and_data(fileName):
    dict = np.load(fileName, allow_pickle=True).item()
    dict_keys = dict.keys()
    ground_truth = ground_truth_set(dict_keys)
    data_values = data_set(dict_keys, dict)

    return ground_truth, data_values

def accuracy(truth, pred):
    tn, fp, fn, tp = confusion_matrix(truth, pred, labels=[0,1]).ravel()
    return (tn+tp)/ (tn+ fp+ fn+ tp)

def three_d_accuracy(truth, pred):
    matrix1 = confusion_matrix(truth, pred, labels=[-1,0,1])
    
    trues1 = matrix1[0][0]+matrix1[1][1]+matrix1[2][2]
    accuracy_percent1 = trues1/len(truth)

    #see if swapped around is better 
    mapping = {-1:-1, 0: 1, 1: 0}
    # Reassign the labels using the mapping
    new_pred = np.array([mapping[label] for label in pred])

    matrix2 = confusion_matrix(truth, new_pred, labels=[-1,0,1])
    
    trues2 = matrix2[0][0]+matrix2[1][1]+matrix2[2][2]
    accuracy_percent2 = trues2/len(truth)

    if (accuracy_percent1 > accuracy_percent2):
        print(matrix1)
        # print("1. ", accuracy_percent1)
        return accuracy_percent1
    # print("2. ", accuracy_percent2)
    print(matrix2)
    return accuracy_percent2

# %%
# 2669 trees  
glcm_truth_test_n , glcm_data_test_n  =  get_truth_and_data('GLCM_testN.npy')
glcm_truth_test , glcm_data_test  =  get_truth_and_data('GLCM_test.npy')

hist_truth_n_test, hist_data_n_test =  get_truth_and_data('hist_testN.npy')
hist_truth_test, hist_data_test =  get_truth_and_data('hist_test.npy')

hog_truth_n_test, hog_data_n_test =  get_truth_and_data('hog_testN.npy')
hog_truth_test, hog_data_test =  get_truth_and_data('hog_test.npy')

lbp_truth_n_test, lbp_data_n_test =  get_truth_and_data('lbp_test_n.npy')
lbp_truth_test, lbp_data_test =  get_truth_and_data('lbp_test.npy')

# %%
glcm_truth_n , glcm_data_n  =  get_truth_and_data('GLCM_n.npy')
glcm_truth , glcm_data  =  get_truth_and_data('GLCM.npy')

hist_truth_n, hist_data_n =  get_truth_and_data('hist_n.npy')
hist_truth, hist_data =  get_truth_and_data('hist.npy')

hog_truth_n, hog_data_n =  get_truth_and_data('hog_n.npy')
hog_truth, hog_data =  get_truth_and_data('hog.npy')

lbp_truth_n, lbp_data_n =  get_truth_and_data('lbp_n.npy')
lbp_truth, lbp_data =  get_truth_and_data('lbp.npy')

# %%
print(np.sum(lbp_truth == 0)) # 14.7%
print(np.sum(lbp_truth_test == 0))

# %%
def dbscan_labels(e, dataset):
    minpt = int(len(dataset)*0.025)
    print("chosen minpt is 0.1 of sample size ", minpt)
    print("the chosen eps: ", e)
    dbscan = DBSCAN(eps = e, min_samples=minpt)
    labels = dbscan.fit_predict(dataset)
    labels = np.array(labels)
    unique = np.unique(labels)
    result = np.sum(labels == -1)
    print("The unique labels are: ", unique)
    print("the amount of noisy samples are: ", result)
    return labels
from sklearn.neighbors import NearestNeighbors

def knn_plot(data):
    nn = int(len(data)*0.025)-1
    neighbors = NearestNeighbors(n_neighbors=nn)
    neighbors_fit = neighbors.fit(data)
    distances, indices = neighbors_fit.kneighbors(data)

    distances = np.sort(distances[:, -1])  # Get the distances to the 4th nearest neighbor

    plt.plot(distances)
    plt.xlabel("Points sorted by distance")
    plt.ylabel("Distance to 4th nearest neighbor")
    plt.title("k-NN Distance Plot")
    plt.show()

def experiment(e, truth, data):
    labels = dbscan_labels(e, data)
    precision = precision_score(truth, labels, labels = [0,1], average = 'weighted')
    recall = recall_score(truth, labels, labels = [0,1], average = 'weighted')
    f1 = f1_score(truth, labels, labels = [0,1], average = 'weighted')
    return precision, recall, f1 

import csv 
def record_results(e, truth, data, dict, name, experi ="dbscan"): 
    precision, recall, f1 = experiment(e, truth,data)
    if name not in dict:
        dict[name] = [precision, recall, f1]

    if not os.path.exists(f"results_{experi}/{name}.csv"):
        with open(f"results_{experi}/{name}.csv", 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(("precision","recall", "f1"))
            writer.writerow((precision, recall, f1))
    else:
        with open(f"results_{experi}/{name}.csv", 'a', newline='') as file:
            writer = csv.writer(file)
            writer.writerow((precision, recall, f1)) 
    
    print(name)
    if dict[name][0] <= precision:
        dict[name][0] = precision
    else:
        print("max precision: ", dict[name][0])

    if dict[name][1] <= recall:
        dict[name][1] = recall
    else:
        print("max recall: ", dict[name][0])

    if dict[name][2] <= f1:
        dict[name][2] = f1
    else:
        print("max f1 : ", dict[name][2])
    
    print("f1 : ", f1 , "\nprecision: ", precision,"\nrecall: ", recall)
    

def experiment_eps(title, eps_array, truth, dataset):
    print(title)
    for i in eps_array:
        labels = dbscan_labels(i, dataset)
        arr = np.array(labels)
        unique = np.unique(labels)
        result = np.sum(arr == -1)
        
        if(len(unique) == 3 or len(unique) == 2 or len(unique) == 4 or len(unique) == 5):
            f1 = f1_score(truth, labels, labels = [0,1], average = 'weighted')
            print("F1 score: ", f1)
            # print("accuracy: ", three_d_accuracy(truth, labels))
        print()

# %%
knn_plot(hog_data_n_test)

# %%
arr = np.linspace(4.81, 4.9, num=10) # results from 3 minpoints 
experiment_eps("hog n data", arr, hog_truth_n_test, hog_data_n_test)

# chosen minpt is 0.1 of sample size  66
# the chosen eps:  4.81
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  1593
# F1 score:  0.028622279390097045
# Out:
# hog n data
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  4.81
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  1593
# F1 score:  0.028622279390097045
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  4.819999999999999
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  1579
# F1 score:  0.028484074801250536
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  4.83
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  1567
# F1 score:  0.028367876758145616
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  4.84
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  1492
# F1 score:  0.02828206407923219
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  4.85
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  1477
# F1 score:  0.028150796032988083
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  4.86
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  1466
# F1 score:  0.0280769712286554
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  4.87
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  1452
# F1 score:  0.028132134872971226
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  4.88
# The unique labels are:  [-1  0  1  2  3]
# the amount of noisy samples are:  1373
# F1 score:  0.05145636370290776
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  4.890000000000001
# The unique labels are:  [-1  0  1  2  3]
# the amount of noisy samples are:  1358
# F1 score:  0.05276501042821679
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  4.9
# The unique labels are:  [-1  0  1  2  3]
# the amount of noisy samples are:  1309
# F1 score:  0.05494930389497792

# %%
knn_plot(hog_data_test)

# %%
arr = np.linspace(3.251, 3.26, num=10)

experiment_eps("hog data", arr, hog_truth_test, hog_data_test)

# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.259
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2370
# F1 score:  0.09413519100886412
# Out:
# hog data
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.251
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2460
# F1 score:  0.04720156814084771
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.252
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2456
# F1 score:  0.04719719545200297
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.2529999999999997
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2453
# F1 score:  0.04790478332087321
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.254
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2419
# F1 score:  0.0703074923326412
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.255
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2414
# F1 score:  0.07237574395317355
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.256
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2407
# F1 score:  0.07581299091362573
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.2569999999999997
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2381
# F1 score:  0.09212619977827989
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.258
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2378
# F1 score:  0.0914485963966632
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.259
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2370
# F1 score:  0.09413519100886412
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.26
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2366
# F1 score:  0.00038779761975787116

# %%
knn_plot(glcm_data_test_n)

# %%
arr = np.linspace(0.071, 0.09, num=20)
experiment_eps("glcm n data", arr, glcm_truth_test_n , glcm_data_test_n)

# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.076
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2514
# F1 score:  0.04726882976564941
# Out:
# glcm n data
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.071
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.072
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.073
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.074
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.075
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.076
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2514
# F1 score:  0.04726882976564941
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.077
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2447
# F1 score:  0.0013356685843214425
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.078
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2397
# F1 score:  0.001223803543758508
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.079
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2263
# F1 score:  0.035560179165680626
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.08
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2177
# F1 score:  0.0023846942982417925
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.08099999999999999
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2102
# F1 score:  0.0030032577996495216
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.08199999999999999
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2022
# F1 score:  0.0027560760877442117
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.08299999999999999
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1959
# F1 score:  0.0025883149345771726
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.08399999999999999
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1900
# F1 score:  0.003339171460803607
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.08499999999999999
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1854
# F1 score:  0.0032044329632624083
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.086
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1807
# F1 score:  0.0030775514558712266
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.087
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1762
# F1 score:  0.0031628169507525073
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.088
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1716
# F1 score:  0.0034300972564499017
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.089
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1680
# F1 score:  0.0038921423206748885
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.09
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1608
# F1 score:  0.00421708926767001

# %%
knn_plot(glcm_data_test)

# %%
arr = np.linspace(291,295, num=10)
experiment_eps("glcm data", arr, glcm_truth_test , glcm_data_test)

# chosen minpt is 0.1 of sample size  66
# the chosen eps:  294.1111111111111
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  1729
# F1 score:  0.1045771853001049
# Out:
# glcm data
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  291.0
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  1820
# F1 score:  0.09797499722590436
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  291.44444444444446
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  1819
# F1 score:  0.09796617044744206
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  291.8888888888889
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  1808
# F1 score:  0.0978962600160331
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  292.3333333333333
# The unique labels are:  [-1  0  1  2  3]
# the amount of noisy samples are:  1756
# F1 score:  0.10334397362322961
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  292.77777777777777
# The unique labels are:  [-1  0  1  2  3]
# the amount of noisy samples are:  1748
# F1 score:  0.10328214563687885
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  293.22222222222223
# The unique labels are:  [-1  0  1  2  3]
# the amount of noisy samples are:  1740
# F1 score:  0.1032126359044342
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  293.6666666666667
# The unique labels are:  [-1  0  1  2  3]
# the amount of noisy samples are:  1740
# F1 score:  0.1032126359044342
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  294.1111111111111
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  1729
# F1 score:  0.1045771853001049
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  294.55555555555554
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1723
# F1 score:  0.02414291900566548
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  295.0
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1720
# F1 score:  0.024086067548038322

# %%
knn_plot(hist_data_n_test)

# %%
#arr = np.linspace(201,400, num=200)
arr = np.linspace(0.01,4, num=40)
experiment_eps("hist n data", arr, hist_truth_n_test, hist_data_n_test)

# chosen minpt is 0.1 of sample size  66
# the chosen eps:  1.34
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  74
# F1 score:  0.6974513447274793
# Out:
# hist n data
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.01
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.1123076923076923
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  656
# F1 score:  0.638751054389798
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.21461538461538462
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  278
# F1 score:  0.6762694252178818
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.3169230769230769
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  212
# F1 score:  0.6809851518278816
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.41923076923076924
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  199
# F1 score:  0.6830778031679847
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.5215384615384615
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  194
# F1 score:  0.6834286348083868
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.6238461538461538
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  190
# F1 score:  0.6836590984483089
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.7261538461538461
# The unique labels are:  [-1  0  1  2  3]
# the amount of noisy samples are:  106
# F1 score:  0.6834894718267464
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.8284615384615385
# The unique labels are:  [-1  0  1  2  3]
# the amount of noisy samples are:  91
# F1 score:  0.6834894718267464
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.9307692307692308
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  86
# F1 score:  0.6837741514756867
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  1.033076923076923
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  79
# F1 score:  0.6834351018132475
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  1.1353846153846154
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  78
# F1 score:  0.6834351018132475
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  1.2376923076923076
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  76
# F1 score:  0.6834351018132475
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  1.34
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  74
# F1 score:  0.6974513447274793
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  1.4423076923076923
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  74
# F1 score:  0.6974513447274793
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  1.5446153846153847
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  8
# F1 score:  0.6974513447274793
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  1.646923076923077
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  8
# F1 score:  0.6974513447274793
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  1.7492307692307691
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  7
# F1 score:  0.6974513447274793
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  1.8515384615384616
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  5
# F1 score:  0.6974513447274793
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  1.9538461538461538
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  5
# F1 score:  0.6974513447274793
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  2.0561538461538458
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  4
# F1 score:  0.6974513447274793
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  2.1584615384615384
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  2.2607692307692306
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  2.363076923076923
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  2.465384615384615
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  2.5676923076923073
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  2.67
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  2.772307692307692
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  2.8746153846153844
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  2.9769230769230766
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.079230769230769
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.1815384615384614
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.2838461538461536
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.386153846153846
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.488461538461538
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.5907692307692307
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.693076923076923
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.795384615384615
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  3.8976923076923073
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  3
# F1 score:  0.07550241099235565
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  4.0
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  3
# F1 score:  0.02646255238802457

# %%
knn_plot(hist_data_test)

# %%
arr = np.linspace(0.0041,0.005, num=10)
experiment_eps("hist data", arr, hist_truth_test, hist_data_test)

# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.004200000000000001
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2295
# F1 score:  0.04244043330528836
# Out:
# hist data
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.0041
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2561
# F1 score:  0.001124881779251469
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.004200000000000001
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2295
# F1 score:  0.04244043330528836
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.0043
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2166
# F1 score:  0.0029412669711104235
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.0044
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2050
# F1 score:  0.0030958081170501237
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.0045000000000000005
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1848
# F1 score:  0.003825186992794917
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.0046
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1713
# F1 score:  0.004372637642297182
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.0047
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1617
# F1 score:  0.004775233435449863
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.0048000000000000004
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1527
# F1 score:  0.006142375932306676
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.0049
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1472
# F1 score:  0.0060804220748369485
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.005
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1369
# F1 score:  0.0062944923192206825

# %%
knn_plot(lbp_data_test)

# %%
arr = np.linspace(0.002,0.011, num=10)
experiment_eps("lbp data", arr, lbp_truth_test, lbp_data_test)

# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.01
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2525
# F1 score:  0.05038290304924796
# Out:
# lbp data
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.002
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.003
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.004
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.005
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.006
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.007
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.008
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009000000000000001
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.01
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2525
# F1 score:  0.05038290304924796
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.011
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  1798
# F1 score:  0.009366804046459348

# %%
knn_plot(lbp_data_n_test)

# %%
arr = np.linspace(0.0096,0.01, num=100)
arr = [0.009701, 0.009702, 0.009703, 0.009704, 0.009705, 0.009706, 0.009707, 0.009708]
experiment_eps("lbp data", arr, lbp_truth_n_test, lbp_data_n_test)

# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.0097010101010101
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2535
# F1 score:  0.038449183583668375

# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00971
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2535
# F1 score:  0.03772670069896626


# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00974
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2534
# F1 score:  0.03772232242870149


# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009749494949494949
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2533
# F1 score:  0.03844040552829722



# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00975
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2518
# F1 score:  0.04914017133210346
# Out:
# lbp data
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.0096
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009604040404040403
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009608080808080807
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00961212121212121
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009616161616161615
# The unique labels are:  [-1]
# the amount of noisy samples are:  2669
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00962020202020202
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2603
# F1 score:  0.0006228565350586779
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009624242424242424
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2603
# F1 score:  0.0006228565350586779
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009628282828282828
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2603
# F1 score:  0.0006228565350586779
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009632323232323232
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2603
# F1 score:  0.0006228565350586779
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009636363636363636
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2603
# F1 score:  0.0006228565350586779
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00964040404040404
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2603
# F1 score:  0.0006228565350586779
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009644444444444443
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2603
# F1 score:  0.0006228565350586779
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009648484848484847
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2603
# F1 score:  0.0006228565350586779
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009652525252525251
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2589
# F1 score:  0.001803977075614393
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009656565656565657
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2589
# F1 score:  0.001803977075614393
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00966060606060606
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2589
# F1 score:  0.001803977075614393
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009664646464646464
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2589
# F1 score:  0.001803977075614393
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009668686868686868
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2589
# F1 score:  0.001803977075614393
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009672727272727272
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2589
# F1 score:  0.001803977075614393
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009676767676767676
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2589
# F1 score:  0.001803977075614393
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00968080808080808
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2589
# F1 score:  0.001803977075614393
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009684848484848484
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2589
# F1 score:  0.001803977075614393
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009688888888888888
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2589
# F1 score:  0.001803977075614393
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009692929292929293
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2588
# F1 score:  0.001799533782324702
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009696969696969697
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2588
# F1 score:  0.001799533782324702
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.0097010101010101
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2535
# F1 score:  0.038449183583668375
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009705050505050505
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2535
# F1 score:  0.03772670069896626
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009709090909090909
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2535
# F1 score:  0.03772670069896626
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009713131313131312
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2535
# F1 score:  0.03772670069896626
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009717171717171716
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2535
# F1 score:  0.03772670069896626
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00972121212121212
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2535
# F1 score:  0.03772670069896626
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009725252525252524
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2535
# F1 score:  0.03772670069896626
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00972929292929293
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2535
# F1 score:  0.03772670069896626
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009733333333333333
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2535
# F1 score:  0.03772670069896626
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009737373737373737
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2534
# F1 score:  0.03772232242870149
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009741414141414141
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2534
# F1 score:  0.03772232242870149
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009745454545454545
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2534
# F1 score:  0.03772232242870149
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009749494949494949
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2533
# F1 score:  0.03844040552829722
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009753535353535353
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2518
# F1 score:  0.04914017133210346
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009757575757575757
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2518
# F1 score:  0.04914017133210346
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00976161616161616
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  2518
# F1 score:  0.04914017133210346
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009765656565656566
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2513
# F1 score:  0.002531568661205229
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00976969696969697
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2513
# F1 score:  0.002531568661205229
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009773737373737374
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2513
# F1 score:  0.002531568661205229
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009777777777777778
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2513
# F1 score:  0.002531568661205229
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009781818181818181
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2513
# F1 score:  0.002531568661205229
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009785858585858585
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2513
# F1 score:  0.002531568661205229
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00978989898989899
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2513
# F1 score:  0.002531568661205229
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009793939393939393
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2512
# F1 score:  0.002526316444065799
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009797979797979797
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2511
# F1 score:  0.002521085975237506
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009802020202020202
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2511
# F1 score:  0.002521085975237506
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009806060606060606
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2511
# F1 score:  0.002521085975237506
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00981010101010101
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2511
# F1 score:  0.002521085975237506
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009814141414141414
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2511
# F1 score:  0.002521085975237506
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009818181818181818
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2509
# F1 score:  0.002510689744411784
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009822222222222222
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2509
# F1 score:  0.002510689744411784
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009826262626262626
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2509
# F1 score:  0.002510689744411784
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00983030303030303
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2471
# F1 score:  0.002793922430683859
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009834343434343433
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2470
# F1 score:  0.0027885905176482026
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009838383838383839
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2470
# F1 score:  0.0027885905176482026
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009842424242424243
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2470
# F1 score:  0.0027885905176482026
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009846464646464647
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2470
# F1 score:  0.0027885905176482026
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00985050505050505
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2470
# F1 score:  0.0027885905176482026
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009854545454545454
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2470
# F1 score:  0.0027885905176482026
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009858585858585858
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2455
# F1 score:  0.0031628169507525073
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009862626262626262
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2455
# F1 score:  0.0031628169507525073
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009866666666666666
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2454
# F1 score:  0.0031569598823251877
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00987070707070707
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2454
# F1 score:  0.0031569598823251877
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009874747474747475
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2454
# F1 score:  0.0031569598823251877
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00987878787878788
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2454
# F1 score:  0.0031569598823251877
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009882828282828283
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2454
# F1 score:  0.0031569598823251877
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009886868686868687
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2454
# F1 score:  0.0031569598823251877
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00989090909090909
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2454
# F1 score:  0.0031569598823251877
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009894949494949495
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2454
# F1 score:  0.0031569598823251877
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009898989898989899
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2454
# F1 score:  0.0031569598823251877
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009903030303030302
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2453
# F1 score:  0.0031511244666462134
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009907070707070706
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2453
# F1 score:  0.0031511244666462134
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009911111111111112
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2453
# F1 score:  0.0031511244666462134
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009915151515151516
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2453
# F1 score:  0.0031511244666462134
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00991919191919192
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2453
# F1 score:  0.0031511244666462134
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009923232323232323
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2444
# F1 score:  0.003542354984842808
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009927272727272727
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2444
# F1 score:  0.003542354984842808
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009931313131313131
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2442
# F1 score:  0.003529520365332508
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009935353535353535
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2437
# F1 score:  0.003935066690972149
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009939393939393939
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2437
# F1 score:  0.003935066690972149
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009943434343434343
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2437
# F1 score:  0.003935066690972149
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009947474747474748
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2436
# F1 score:  0.0039280146001281135
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009951515151515152
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2436
# F1 score:  0.0039280146001281135
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009955555555555556
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2436
# F1 score:  0.0039280146001281135
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00995959595959596
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2433
# F1 score:  0.00390700917445898
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009963636363636364
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2433
# F1 score:  0.00390700917445898
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009967676767676768
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2429
# F1 score:  0.0038793489325159073
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009971717171717171
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2418
# F1 score:  0.004228071270971234
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009975757575757575
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2418
# F1 score:  0.004228071270971234
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.00997979797979798
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2418
# F1 score:  0.004228071270971234
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009983838383838385
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2417
# F1 score:  0.0042207435911255295
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009987878787878789
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2417
# F1 score:  0.0042207435911255295
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009991919191919192
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2416
# F1 score:  0.004634785393230751
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.009995959595959596
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2414
# F1 score:  0.004618803374633403
#
# chosen minpt is 0.1 of sample size  66
# the chosen eps:  0.01
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  2414
# F1 score:  0.004618803374633403

# %%
p_r_f1 ={}

# %%
# official min points 
record_results(4.81, hog_truth_n , hog_data_n,  p_r_f1,   "hog_n" )
record_results(3.259, hog_truth , hog_data,  p_r_f1,   "hog" )

record_results(0.076, glcm_truth_n , glcm_data_n,  p_r_f1,   "glcm_n" )
record_results(294, glcm_truth , glcm_data,  p_r_f1,   "glcm" )

record_results(1.34, hist_truth_n , hist_data_n,  p_r_f1,   "hist_n" )
record_results(0.042, hist_truth , hist_data,  p_r_f1,   "hist" )


record_results(0.01, lbp_truth , lbp_data,  p_r_f1,   "lbp" )
record_results( 0.00975, lbp_truth_n , lbp_data_n,  p_r_f1,   "lbp_n" )
# Out:
# chosen minpt is 0.1 of sample size  326
# the chosen eps:  4.81
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  6148
# hog_n
# f1 :  0.06051939559855427
# precision:  0.41348380410793906
# recall:  0.05854442488712023
# chosen minpt is 0.1 of sample size  326
# the chosen eps:  3.259
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  8821
# hog
# max precision:  0.01926030657929139
# max recall:  0.01926030657929139
# max f1 :  0.03337667260603869
# f1 :  0.0009055353604235524
# precision:  0.0006575048318854949
# recall:  0.00145404453968011
# chosen minpt is 0.1 of sample size  326
# the chosen eps:  0.076
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# The unique labels are:  [-1]
# the amount of noisy samples are:  13067
# glcm_n
# f1 :  0.0
# precision:  0.0
# recall:  0.0
# chosen minpt is 0.1 of sample size  326
# the chosen eps:  294
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  11227
# glcm
# max recall:  0.877355909445252
# max f1 :  0.39071973278948446
# f1 :  0.15620473484885586
# precision:  0.877355909445252
# recall:  0.08823754496058774
# chosen minpt is 0.1 of sample size  326
# the chosen eps:  1.34
# The unique labels are:  [-1  0  1  2]
# the amount of noisy samples are:  42
# hist_n
# f1 :  0.12159110592181821
# precision:  0.8130221075910423
# recall:  0.14150149230886966
# chosen minpt is 0.1 of sample size  326
# the chosen eps:  0.042
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  13
# hist
# f1 :  0.03760217871687778
# precision:  0.02156637904498728
# recall:  0.14662891252774163
# chosen minpt is 0.1 of sample size  326
# the chosen eps:  0.01
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# The unique labels are:  [-1]
# the amount of noisy samples are:  13067
# lbp
# f1 :  0.0
# precision:  0.0
# recall:  0.0
# chosen minpt is 0.1 of sample size  326
# the chosen eps:  0.00975
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  12734
# lbp_n
# f1 :  0.0024782649943948616
# precision:  0.00838368022878622
# recall:  0.00145404453968011
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# results from minpt at 3 
record_results(3.655, hog_truth , hog_data,  p_r_f1,   "hog" )
record_results(3.78, hog_truth_n , hog_data_n,  p_r_f1,   "hog_n" )
record_results(613.5, glcm_truth , glcm_data,  p_r_f1,   "glcm" )
record_results(0.05, glcm_truth_n , glcm_data_n,  p_r_f1,   "glcm_n" )
record_results(374, hist_truth_n , hist_data_n,  p_r_f1,   "hist_n" )
record_results(373, hist_truth , hist_data,  p_r_f1,   "hist" )
record_results(0.01789, lbp_truth , lbp_data,  p_r_f1,   "lbp" )

# lbp
# f1 :  0.03706204445867489 
# precision:  0.5898159177581467 
# recall:  0.14234330756868446

#record_results( , lbp_truth_n , lbp_data_n,  p_r_f1,   "lbp_n" )
# Out:
# chosen minpt is 0.1 of sample size  326
# the chosen eps:  3.655
# The unique labels are:  [-1  0]
# the amount of noisy samples are:  609
# hog
# f1 :  0.03337667260603869
# precision:  0.01926030657929139
# recall:  0.12497130175250631
# chosen minpt is 0.1 of sample size  326
# the chosen eps:  3.78
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb Cell 26 line 3
#       <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> # results from minpt at 3
#       <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> record_results(3.655, hog_truth , hog_data,  p_r_f1,   "hog" )
# ----> <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> record_results(3.78, hog_truth_n , hog_data_n,  p_r_f1,   "hog_n" )
#       <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> record_results(613.5, glcm_truth , glcm_data,  p_r_f1,   "glcm" )
#       <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a> record_results(0.05, glcm_truth_n , glcm_data_n,  p_r_f1,   "glcm_n" )
#
# /Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb Cell 26 line 3
#      <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=36'>37</a> def record_results(e, truth, data, dict, name, experi ="dbscan"):
# ---> <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=37'>38</a>     precision, recall, f1 = experiment(e, truth,data)
#      <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=38'>39</a>     if name not in dict:
#      <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=39'>40</a>         dict[name] = [precision, recall, f1]
#
# /Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb Cell 26 line 3
#      <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=28'>29</a> def experiment(e, truth, data):
# ---> <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=29'>30</a>     labels = dbscan_labels(e, data)
#      <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=30'>31</a>     precision = precision_score(truth, labels, labels = [0,1], average = 'weighted')
#      <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=31'>32</a>     recall = recall_score(truth, labels, labels = [0,1], average = 'weighted')
#
# /Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb Cell 26 line 6
#       <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> print("the chosen eps: ", e)
#       <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=4'>5</a> dbscan = DBSCAN(eps = e, min_samples=minpt)
# ----> <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=5'>6</a> labels = dbscan.fit_predict(dataset)
#       <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=6'>7</a> labels = np.array(labels)
#       <a href='vscode-notebook-cell:/Users/catherineli/Library/CloudStorage/OneDrive-UniversityofCapeTown/2.CSC2005Z/code-related/DBSCAN.ipynb#X34sZmlsZQ%3D%3D?line=7'>8</a> unique = np.unique(labels)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/cluster/_dbscan.py:474, in DBSCAN.fit_predict(self, X, y, sample_weight)
#     449 def fit_predict(self, X, y=None, sample_weight=None):
#     450     """Compute clusters from a data or distance matrix and predict labels.
#     451
#     452     Parameters
#    (...)
#     472         Cluster labels. Noisy samples are given the label -1.
#     473     """
# --> 474     self.fit(X, sample_weight=sample_weight)
#     475     return self.labels_
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/cluster/_dbscan.py:422, in DBSCAN.fit(self, X, y, sample_weight)
#     420 neighbors_model.fit(X)
#     421 # This has worst case O(n^2) memory complexity
# --> 422 neighborhoods = neighbors_model.radius_neighbors(X, return_distance=False)
#     424 if sample_weight is None:
#     425     n_neighbors = np.array([len(neighbors) for neighbors in neighborhoods])
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/neighbors/_base.py:1185, in RadiusNeighborsMixin.radius_neighbors(self, X, radius, return_distance, sort_results)
#    1177 use_pairwise_distances_reductions = (
#    1178     self._fit_method == "brute"
#    1179     and RadiusNeighbors.is_usable_for(
#    1180         X if X is not None else self._fit_X, self._fit_X, self.effective_metric_
#    1181     )
#    1182 )
#    1184 if use_pairwise_distances_reductions:
# -> 1185     results = RadiusNeighbors.compute(
#    1186         X=X,
#    1187         Y=self._fit_X,
#    1188         radius=radius,
#    1189         metric=self.effective_metric_,
#    1190         metric_kwargs=self.effective_metric_params_,
#    1191         strategy="auto",
#    1192         return_distance=return_distance,
#    1193         sort_results=sort_results,
#    1194     )
#    1196 elif (
#    1197     self._fit_method == "brute" and self.metric == "precomputed" and issparse(X)
#    1198 ):
#    1199     results = _radius_neighbors_from_graph(
#    1200         X, radius=radius, return_distance=return_distance
#    1201     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_pairwise_distances_reduction/_dispatcher.py:422, in RadiusNeighbors.compute(cls, X, Y, radius, metric, chunk_size, metric_kwargs, strategy, return_distance, sort_results)
#     336 """Return the results of the reduction for the given arguments.
#     337
#     338 Parameters
#    (...)
#     419 returns.
#     420 """
#     421 if X.dtype == Y.dtype == np.float64:
# --> 422     return RadiusNeighbors64.compute(
#     423         X=X,
#     424         Y=Y,
#     425         radius=radius,
#     426         metric=metric,
#     427         chunk_size=chunk_size,
#     428         metric_kwargs=metric_kwargs,
#     429         strategy=strategy,
#     430         sort_results=sort_results,
#     431         return_distance=return_distance,
#     432     )
#     434 if X.dtype == Y.dtype == np.float32:
#     435     return RadiusNeighbors32.compute(
#     436         X=X,
#     437         Y=Y,
#    (...)
#     444         return_distance=return_distance,
#     445     )
#
# File sklearn/metrics/_pairwise_distances_reduction/_radius_neighbors.pyx:112, in sklearn.metrics._pairwise_distances_reduction._radius_neighbors.RadiusNeighbors64.compute()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/threadpoolctl.py:592, in _ThreadpoolLimiter.__exit__(self, type, value, traceback)
#     589 def __enter__(self):
#     590     return self
# --> 592 def __exit__(self, type, value, traceback):
#     593     self.restore_original_limits()
#     595 @classmethod
#     596 def wrap(cls, controller, *, limits=None, user_api=None):
#
# KeyboardInterrupt:

# %%
# Out:
# chosen minpt is 0.1 of sample size  326
# the chosen eps:  3
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  19
# hist_n
# f1 :  0.10121822653544152
# precision:  0.7894645715985369
# recall:  0.17624550394122598

# %%
record_results(306, glcm_truth , glcm_data,  p_r_f1,   "glcm" )
# Out:
# chosen minpt is 0.1 of sample size  326
# the chosen eps:  306
# The unique labels are:  [-1  0  1]
# the amount of noisy samples are:  8679
# glcm
# max precision:  0.877355909445252
# f1 :  0.39071973278948446
# precision:  0.834543283997745
# recall:  0.2583607561031606

# %%
# appendix section 
record_results(306, glcm_truth , glcm_data,  p_r_f1,   "glcm" )
record_results(3, hist_truth_n , hist_data_n,  p_r_f1,   "hist_n" )


record_results(4.81, hog_truth_n , hog_data_n,  p_r_f1,   "hog_n" )
record_results(3.259, hog_truth , hog_data,  p_r_f1,   "hog" )

record_results(0.076, glcm_truth_n , glcm_data_n,  p_r_f1,   "glcm_n" )


record_results(373, hist_truth , hist_data,  p_r_f1,   "hist" )
record_results(0.01789, lbp_truth , lbp_data,  p_r_f1,   "lbp" )
record_results( 0, lbp_truth_n , lbp_data_n,  p_r_f1,   "lbp_n" )
